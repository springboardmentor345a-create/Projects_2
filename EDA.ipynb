# %% [markdown]
# # Step 1: Import pandas
# import pandas as pd
#
# # Step 2: Load your dataset
# df = pd.read_excel("Goals & Assist.xlsx")
#
# # Step 3: See first few rows
# print("✅ Dataset loaded successfully!")
# print(df.head())
