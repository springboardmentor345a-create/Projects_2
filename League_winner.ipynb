# %%
import pandas as pd
from IPython.display import display, HTML


df = pd.read_csv("C:/Users/Hp/Downloads/ScoreSight_ML_Season_LeagueWinner_Champion.csv")

pd.set_option('display.max_rows', None)

display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>season</th>
#       <th>team</th>
#       <th>matches_played</th>
#       <th>wins</th>
#       <th>draws</th>
#       <th>losses</th>
#       <th>points_per_game</th>
#       <th>goals_scored</th>
#       <th>goals_conceded</th>
#       <th>goal_difference</th>
#       <th>target_total_points</th>
#       <th>target_league_position</th>
#       <th>target_champion</th>
#       <th>target_top_4</th>
#       <th>target_top_6</th>
#       <th>target_relegated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2015-16</td>
#       <td>Bournemouth</td>
#       <td>38</td>
#       <td>11</td>
#       <td>9</td>
#       <td>18</td>
#       <td>1.105263</td>
#       <td>45.0</td>
#       <td>67.0</td>
#       <td>-22.0</td>
#       <td>42</td>
#       <td>15</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
# ...
